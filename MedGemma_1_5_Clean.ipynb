# %% [markdown]
# # MedGemma 1.5 - 胸部 X 光报告生成与 RadGraph F1 评估
#
# **模型**: Google MedGemma 1.5 (4B)
#
# **数据集**: MIMIC-CXR (233 samples)
#
# **评估指标**: RadGraph F1 Score
#
# **GPU**: A100 (80GB)
#
# ---
#
# ## ⚠️ 环境要求
#
# - **Python**: **3.10 或 3.11（必需！）** Colab 默认 3.12 不兼容
# - **GPU**: A100（80GB）
# - **依赖**: transformers 4.47+, radgraph
# - **Google Drive**: 需上传 `mimic_eval_single_image_final_233.csv`
#
# ## 🚨 使用前必读
#
# 1. **先运行 Step 0**（安装 Python 3.10）
# 2. **点击 Runtime → Restart Runtime**
# 3. **从 Step 1 开始 Run All**
#
# ---
#
# ## 流程
#
# 0. **安装 Python 3.10**（必需！）
# 1. 安装依赖（transformers + radgraph）
# 2. 挂载 Google Drive
# 3. 下载 MIMIC-CXR 数据集（kagglehub）
# 4. 对齐 233 CSV 的图片路径
# 5. 加载 MedGemma 1.5 模型
# 6. 批量生成报告（233 samples）
# 7. RadGraph F1 评估

# %% [markdown]
# ## Step 0: 安装 Python 3.10（必需！）
#
# ⚠️ **重要**：Colab 默认是 Python 3.12，但某些依赖需要 3.10 或 3.11。
#
# 运行后需要 **Restart Runtime**（Runtime → Restart Runtime）。

# %%
import pandas as pd

csv_path = "/content/drive/MyDrive/medgamma/medgemma_reports_233.csv"
df_results = pd.read_csv(csv_path)

print(f"✅ 已加载 {len(df_results)} 条报告")
print(f"\n数据列：{df_results.columns.tolist()}")
# Out:
# ✅ 已加载 233 条报告
#
# 数据列：['subject_id', 'View', 'Image_Path', 'Ground_Truth', 'Generated_Report']

# %% [markdown]
# ## Step 1: 安装依赖
#
# ⚠️ **前置条件**：确保已安装 Python 3.10（Step 0）并重启了 Runtime。

# %%
import sys

print(f"当前 Python 版本: {sys.version}")

# 检查 Python 版本
py_major = sys.version_info.major
py_minor = sys.version_info.minor

if py_major == 3 and py_minor in [10, 11]:
    print(f"✅ Python 3.{py_minor} 符合要求")
elif py_major == 3 and py_minor == 12:
    print("\\n" + "="*70)
    print("ℹ️ 检测到 Python 3.12")
    print("\\ntransformers 5.x 和 radgraph 都支持 Python 3.12，可以直接使用！")
    print("\\n如果遇到兼容性问题，可以尝试：")
    print("1. 降级 transformers：pip install transformers==4.47.1")
    print("2. 或在 Colab 设置中选择旧版 runtime")
    print("="*70)
    print("\\n✅ 继续使用 Python 3.12（建议先尝试）")
else:
    print(f"\\n⚠️ 未知 Python 版本: {py_major}.{py_minor}")
    print("建议使用 Python 3.10-3.12")

print("\\n跳过 Python 安装，直接进入 Step 1")
# Out:
# 当前 Python 版本: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# \n======================================================================
# ℹ️ 检测到 Python 3.12
# \ntransformers 5.x 和 radgraph 都支持 Python 3.12，可以直接使用！
# \n如果遇到兼容性问题，可以尝试：
# 1. 降级 transformers：pip install transformers==4.47.1
# 2. 或在 Colab 设置中选择旧版 runtime
# ======================================================================
# \n✅ 继续使用 Python 3.12（建议先尝试）
# \n跳过 Python 安装，直接进入 Step 1

# %% [markdown]
# ## Step 2: 挂载 Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive 已挂载")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Google Drive 已挂载

# %%
import sys

# 验证 Python 版本
py_version = f"{sys.version_info.major}.{sys.version_info.minor}"
print(f"当前 Python 版本: {py_version}")

if sys.version_info.major == 3 and sys.version_info.minor in [10, 11, 12]:
    print(f"✅ Python {py_version} 兼容")
else:
    print(f"\n⚠️ 警告：当前版本 {py_version} 未测试，推荐 3.10-3.12")

# 安装依赖
print("\n正在安装依赖...")
# !pip install -U -q transformers
# !pip install -q radgraph
print("\n✅ 依赖安装完成")
# Out:
# 当前 Python 版本: 3.12
# ✅ Python 3.12 兼容
#
# 正在安装依赖...
#
# ✅ 依赖安装完成

# %% [markdown]
# ## Step 3: 下载 MIMIC-CXR 数据集
#
# 使用 kagglehub 下载 MIMIC-CXR 数据集（~18GB）。首次运行需要 5-10 分钟。

# %%
import kagglehub
import os

print("🚀 开始下载 MIMIC-CXR 数据集（~18GB，首次运行需要 5-10 分钟）...")

# kagglehub 会自动缓存，第二次运行会很快
dataset_path = kagglehub.dataset_download("simhadrisadaram/mimic-cxr-dataset")

print(f"✅ 数据集下载完成！")
print(f"📂 存储路径: {dataset_path}")

# 验证文件结构
print("\n--- 文件夹结构预览 ---")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = '  ' * level
    print(f"{indent}{os.path.basename(root)}/")
    if level > 1: break  # 只显示前 2 层
# Out:
# 🚀 开始下载 MIMIC-CXR 数据集（~18GB，首次运行需要 5-10 分钟）...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/simhadrisadaram/mimic-cxr-dataset?dataset_version_number=2...
# 100%|██████████| 16.5G/16.5G [13:25<00:00, 22.0MB/s]
# Extracting files...
# ✅ 数据集下载完成！
# 📂 存储路径: /root/.cache/kagglehub/datasets/simhadrisadaram/mimic-cxr-dataset/versions/2
#
# --- 文件夹结构预览 ---
# 2/
#   official_data_iccv_final/
#     files/

# %% [markdown]
# ## Step 4: 加载 233 CSV 并对齐路径
#
# 读取 `mimic_eval_single_image_final_233.csv`，并将 CSV 中的路径对齐到 kagglehub 下载的实际路径。

# %%
import pandas as pd
import os

# ✅ 使用 233 CSV
csv_path = "/content/drive/MyDrive/medgamma/mimic_eval_single_image_final_233.csv"

if not os.path.exists(csv_path):
    print(f"❌ 找不到 CSV 文件: {csv_path}")
    print("\n请确保 233 CSV 已上传到 Google Drive 的 medgamma 文件夹中！")
    raise FileNotFoundError(csv_path)

print(f"📂 读取 CSV: {csv_path}")
df = pd.read_csv(csv_path)
print(f"✅ 加载成功！共 {len(df)} 条数据")
print(f"\n列名: {list(df.columns)}")

# ==========================================
# 路径对齐函数
# ==========================================
dataset_root = f"{dataset_path}/official_data_iccv_final"

def fix_image_path(path_in_csv):
    """
    将 233 CSV 中的路径对齐到 kagglehub 下载的实际路径
    CSV 格式: /kaggle/input/mimic-cxr-dataset/official_data_iccv_final/files/...
    实际格式: {dataset_root}/files/...
    """
    if pd.isna(path_in_csv):
        return None

    path_str = str(path_in_csv).strip()

    # 提取从 files/ 开始的相对路径
    if 'files/' in path_str:
        relative_part = path_str.split('files/', 1)[1]
        full_path = os.path.join(dataset_root, 'files', relative_part)
        return full_path if os.path.exists(full_path) else None

    return None

# 应用路径修正
print("\n🔄 正在对齐图片路径...")
if 'Image_Path' in df.columns:
    df['Image_Path'] = df['Image_Path'].apply(fix_image_path)
    # 验证
    valid_count = df['Image_Path'].notna().sum()
    print(f"✅ 路径对齐完成！有效路径: {valid_count}/{len(df)}")

    # 显示第一个有效路径
    first_valid = df['Image_Path'].dropna().iloc[0]
    print(f"示例路径: {first_valid}")
    print(f"文件存在: {os.path.exists(first_valid)}")
else:
    print("❌ CSV 中没有 Image_Path 列！")
# Out:
# 📂 读取 CSV: /content/drive/MyDrive/medgamma/mimic_eval_single_image_final_233.csv
# ✅ 加载成功！共 233 条数据
#
# 列名: ['subject_id', 'View', 'Image_Path', 'Ground_Truth', 'Generated_Report']
#
# 🔄 正在对齐图片路径...
# ✅ 路径对齐完成！有效路径: 233/233
# 示例路径: /root/.cache/kagglehub/datasets/simhadrisadaram/mimic-cxr-dataset/versions/2/official_data_iccv_final/files/p10/p10075925/s51010496/2d783c8a-492984b7-28aaf571-bfc30156-61ab26f6.jpg
# 文件存在: True

# %% [markdown]
# ## Step 5: 加载 MedGemma 1.5 模型

# %%
from huggingface_hub import login
from google.colab import userdata

try:
    # 使用你已设置的 Secret 名称（zhuxirui11）
    hf_token = userdata.get('zhuxirui11')
    login(token=hf_token)
    print("✅ HuggingFace 登录成功！")
except Exception as e:
    print("❌ 登录失败！")
    print(f"错误信息: {e}")
    print("\n请确认：")
    print("1. 已在 https://huggingface.co/google/medgemma-1.5-4b-it 申请访问权限")
    print("2. 已在 Colab 左侧 🔑 Secrets 中添加 zhuxirui11")
    print("3. 已勾选 'Notebook access'（开关是蓝色的）")
    raise
# Out:
# ✅ HuggingFace 登录成功！

# %%
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText

model_id = "google/medgemma-1.5-4b-it"

print(f"🤖 正在加载模型: {model_id}...")
print("⚠️ 首次加载需要下载 ~8GB 权重，请耐心等待...\n")

processor = AutoProcessor.from_pretrained(model_id, trust_remote_code=True)
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,  # A100 支持 BF16
    device_map="auto",
    trust_remote_code=True
)

print(f"✅ 模型加载成功！")
print(f"Device: {model.device}")
if torch.cuda.is_available():
    mem_gb = torch.cuda.memory_allocated(0) / (1024**3)
    print(f"GPU 显存占用: {mem_gb:.2f} GB")
# Out:
# 🤖 正在加载模型: google/medgemma-1.5-4b-it...
# ⚠️ 首次加载需要下载 ~8GB 权重，请耐心等待...
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# The image processor of type `Gemma3ImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json:   0%|          | 0.00/2.55k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# ✅ 模型加载成功！
# Device: cuda:0
# GPU 显存占用: 8.01 GB

# %% [markdown]
# ## Step 6: 批量生成报告（233 samples）
#
# 对 233 张胸部 X 光图片生成放射学报告。

# %%
import re
from PIL import Image
from tqdm import tqdm

def generate_one_report(image_path, view_position):
    """
    为单张图片生成放射学报告
    """
    # 提示词
    prompt_text = (
        f"You are an expert radiologist. Describe this {view_position} view chest X-ray. "
        "Provide a concise report consisting of Findings and Impression. "
        "Focus on the heart, lungs, mediastinum, pleural space, and bones. "
        "Do NOT use bullet points, asterisks, or section headers. "
        "Do NOT include disclaimers or 'AI' warnings. "
        "Output pure medical text only."
    )

    try:
        pil_image = Image.open(image_path).convert("RGB")
    except Exception as e:
        return f"ERROR_IMAGE_LOAD: {e}"

    # 构建输入
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": pil_image},
                {"type": "text", "text": prompt_text}
            ]
        }
    ]

    inputs = processor.apply_chat_template(
        messages, add_generation_prompt=True, tokenize=True,
        return_dict=True, return_tensors="pt"
    ).to(model.device, dtype=torch.bfloat16)

    input_len = inputs["input_ids"].shape[-1]

    # 推理
    with torch.inference_mode():
        generation = model.generate(
            **inputs,
            max_new_tokens=300,
            do_sample=False
        )
        generation = generation[0][input_len:]  # 裁剪掉 prompt

    # ✅ 解码并强力清洗，去除格式标记
    raw_text = processor.decode(generation, skip_special_tokens=True)
    clean_text = raw_text.replace("Findings:", "").replace("Impression:", "")
    clean_text = clean_text.replace("**", "").replace("*", "")  # 去除 markdown
    clean_text = clean_text.replace("###", "").replace("##", "").replace("#", "")
    clean_text = re.sub(r'\s+', ' ', clean_text).strip()

    return clean_text

# ==========================================
# 批量生成
# ==========================================
print(f"\n🚀 开始批量生成报告（共 {len(df)} 条）...\n")

results = []
skipped_count = 0

for idx, row in tqdm(df.iterrows(), total=len(df), desc="生成报告"):
    try:
        # ✅ 使用 Image_Path 列
        img_path = row.get('Image_Path')
        view = row.get('View', 'PA')

        # 验证路径
        if not img_path or not os.path.exists(img_path):
            skipped_count += 1
            continue

        # 生成报告
        generated_report = generate_one_report(img_path, view)

        # 检查错误
        if "ERROR_IMAGE_LOAD" in generated_report:
            skipped_count += 1
            continue

        # ✅ Ground_Truth 列
        gt_col = 'Ground_Truth' if 'Ground_Truth' in df.columns else 'text'
        ground_truth = str(row.get(gt_col, '')).strip()

        # 保存结果
        results.append({
            "subject_id": row.get('subject_id', idx),
            "View": view,
            "Image_Path": img_path,
            "Ground_Truth": ground_truth,
            "Generated_Report": generated_report
        })

    except Exception as e:
        print(f"\n❌ Error at index {idx}: {e}")
        skipped_count += 1
        continue

# 保存结果
df_results = pd.DataFrame(results)
output_path = "/content/drive/MyDrive/medgamma/medgemma_reports_233.csv"
df_results.to_csv(output_path, index=False)

print(f"\n✅ 报告生成完成！")
print(f"成功生成: {len(results)} 条")
print(f"跳过: {skipped_count} 条")
print(f"结果已保存至: {output_path}")

# 预览前 3 条
print("\n--- 前 3 条报告预览 ---")
for i in range(min(3, len(df_results))):
    print(f"\n[{i+1}] Subject: {df_results.iloc[i]['subject_id']}")
    print(f"Ground Truth: {df_results.iloc[i]['Ground_Truth'][:100]}...")
    print(f"Generated: {df_results.iloc[i]['Generated_Report'][:100]}...")
# Out:
# 🚀 开始批量生成报告（共 233 条）...
# 生成报告:   0%|          | 0/233 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   0%|          | 1/233 [00:04<17:13,  4.45s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   1%|          | 2/233 [00:07<14:44,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   1%|▏         | 3/233 [00:11<14:37,  3.82s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   2%|▏         | 4/233 [00:16<16:27,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   2%|▏         | 5/233 [00:20<15:03,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   3%|▎         | 6/233 [00:25<16:16,  4.30s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   3%|▎         | 7/233 [00:28<14:58,  3.97s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   3%|▎         | 8/233 [00:31<14:11,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   4%|▍         | 9/233 [00:35<13:42,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   4%|▍         | 10/233 [00:38<13:38,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   5%|▍         | 11/233 [00:42<13:13,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   5%|▌         | 12/233 [00:46<13:53,  3.77s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   6%|▌         | 13/233 [00:49<12:39,  3.45s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   6%|▌         | 14/233 [00:52<12:26,  3.41s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   6%|▋         | 15/233 [00:55<12:16,  3.38s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   7%|▋         | 16/233 [00:59<12:11,  3.37s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   7%|▋         | 17/233 [01:02<12:06,  3.36s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   8%|▊         | 18/233 [01:05<11:59,  3.35s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   8%|▊         | 19/233 [01:09<11:53,  3.34s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   9%|▊         | 20/233 [01:12<11:53,  3.35s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   9%|▉         | 21/233 [01:15<11:50,  3.35s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:   9%|▉         | 22/233 [01:19<12:23,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  10%|▉         | 23/233 [01:24<13:46,  3.93s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  10%|█         | 24/233 [01:27<13:02,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  11%|█         | 25/233 [01:31<12:32,  3.62s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  11%|█         | 26/233 [01:36<14:07,  4.09s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  12%|█▏        | 27/233 [01:40<14:16,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  12%|█▏        | 28/233 [01:45<15:09,  4.44s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  12%|█▏        | 29/233 [01:49<14:38,  4.31s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  13%|█▎        | 30/233 [01:53<13:36,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  13%|█▎        | 31/233 [01:56<13:15,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  14%|█▎        | 32/233 [02:02<14:28,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  14%|█▍        | 33/233 [02:05<13:24,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  15%|█▍        | 34/233 [02:08<12:39,  3.82s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  15%|█▌        | 35/233 [02:13<13:39,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  15%|█▌        | 36/233 [02:17<13:34,  4.13s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  16%|█▌        | 37/233 [02:20<12:30,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  16%|█▋        | 38/233 [02:24<11:57,  3.68s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  17%|█▋        | 39/233 [02:28<12:29,  3.86s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  17%|█▋        | 40/233 [02:31<11:54,  3.70s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  18%|█▊        | 41/233 [02:35<11:30,  3.60s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  18%|█▊        | 42/233 [02:38<11:13,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  18%|█▊        | 43/233 [02:42<11:50,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  19%|█▉        | 44/233 [02:46<11:24,  3.62s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  19%|█▉        | 45/233 [02:51<12:44,  4.07s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  20%|█▉        | 46/233 [02:54<11:59,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  20%|██        | 47/233 [02:59<13:07,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  21%|██        | 48/233 [03:02<11:58,  3.88s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  21%|██        | 49/233 [03:06<11:23,  3.71s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  21%|██▏       | 50/233 [03:09<11:00,  3.61s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  22%|██▏       | 51/233 [03:12<10:43,  3.54s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  22%|██▏       | 52/233 [03:16<10:19,  3.42s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  23%|██▎       | 53/233 [03:19<10:11,  3.39s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  23%|██▎       | 54/233 [03:23<10:32,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  24%|██▎       | 55/233 [03:26<10:40,  3.60s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  24%|██▍       | 56/233 [03:31<11:25,  3.87s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  24%|██▍       | 57/233 [03:34<10:55,  3.72s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  25%|██▍       | 58/233 [03:40<12:49,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  25%|██▌       | 59/233 [03:44<11:56,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  26%|██▌       | 60/233 [03:47<11:11,  3.88s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  26%|██▌       | 61/233 [03:52<11:50,  4.13s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  27%|██▋       | 62/233 [03:56<11:33,  4.05s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  27%|██▋       | 63/233 [04:01<12:44,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  27%|██▋       | 64/233 [04:05<11:42,  4.16s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  28%|██▊       | 65/233 [04:10<12:38,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  28%|██▊       | 66/233 [04:13<11:38,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  29%|██▉       | 67/233 [04:17<10:52,  3.93s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  29%|██▉       | 68/233 [04:20<10:19,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  30%|██▉       | 69/233 [04:23<09:54,  3.63s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  30%|███       | 70/233 [04:27<09:39,  3.56s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  30%|███       | 71/233 [04:31<10:05,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  31%|███       | 72/233 [04:34<09:40,  3.61s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  31%|███▏      | 73/233 [04:38<09:24,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  32%|███▏      | 74/233 [04:41<09:12,  3.48s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  32%|███▏      | 75/233 [04:44<09:02,  3.43s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  33%|███▎      | 76/233 [04:48<09:31,  3.64s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  33%|███▎      | 77/233 [04:52<09:33,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  33%|███▎      | 78/233 [04:55<09:13,  3.57s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  34%|███▍      | 79/233 [05:00<10:15,  4.00s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  34%|███▍      | 80/233 [05:05<10:32,  4.13s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  35%|███▍      | 81/233 [05:08<09:52,  3.89s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  35%|███▌      | 82/233 [05:12<09:57,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  36%|███▌      | 83/233 [05:16<09:27,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  36%|███▌      | 84/233 [05:19<09:04,  3.66s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  36%|███▋      | 85/233 [05:23<09:00,  3.65s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  37%|███▋      | 86/233 [05:26<08:44,  3.57s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  37%|███▋      | 87/233 [05:30<08:57,  3.68s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  38%|███▊      | 88/233 [05:33<08:39,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  38%|███▊      | 89/233 [05:37<08:26,  3.52s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  39%|███▊      | 90/233 [05:40<08:18,  3.49s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  39%|███▉      | 91/233 [05:44<08:11,  3.46s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  39%|███▉      | 92/233 [05:47<07:46,  3.31s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  40%|███▉      | 93/233 [05:51<08:33,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  40%|████      | 94/233 [05:56<09:04,  3.92s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  41%|████      | 95/233 [05:59<08:36,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  41%|████      | 96/233 [06:02<08:15,  3.62s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  42%|████▏     | 97/233 [06:06<08:28,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  42%|████▏     | 98/233 [06:10<08:40,  3.86s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  42%|████▏     | 99/233 [06:14<08:15,  3.70s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  43%|████▎     | 100/233 [06:17<08:10,  3.69s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  43%|████▎     | 101/233 [06:21<07:48,  3.55s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  44%|████▍     | 102/233 [06:24<07:51,  3.60s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  44%|████▍     | 103/233 [06:29<08:20,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  45%|████▍     | 104/233 [06:33<08:25,  3.92s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  45%|████▌     | 105/233 [06:37<08:13,  3.86s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  45%|████▌     | 106/233 [06:40<08:13,  3.89s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  46%|████▌     | 107/233 [06:44<07:53,  3.76s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  46%|████▋     | 108/233 [06:48<08:00,  3.84s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  47%|████▋     | 109/233 [06:51<07:37,  3.69s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  47%|████▋     | 110/233 [06:55<07:41,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  48%|████▊     | 111/233 [07:00<08:15,  4.06s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  48%|████▊     | 112/233 [07:03<07:45,  3.84s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  48%|████▊     | 113/233 [07:08<07:55,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  49%|████▉     | 114/233 [07:12<08:22,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  49%|████▉     | 115/233 [07:16<07:46,  3.95s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  50%|████▉     | 116/233 [07:19<07:24,  3.80s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  50%|█████     | 117/233 [07:22<07:04,  3.66s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  51%|█████     | 118/233 [07:26<06:50,  3.57s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  51%|█████     | 119/233 [07:30<07:18,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  52%|█████▏    | 120/233 [07:34<06:57,  3.70s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  52%|█████▏    | 121/233 [07:37<06:40,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  52%|█████▏    | 122/233 [07:40<06:29,  3.51s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  53%|█████▎    | 123/233 [07:44<06:22,  3.47s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  53%|█████▎    | 124/233 [07:47<06:14,  3.43s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  54%|█████▎    | 125/233 [07:52<06:43,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  54%|█████▍    | 126/233 [07:55<06:28,  3.63s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  55%|█████▍    | 127/233 [07:58<06:17,  3.56s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  55%|█████▍    | 128/233 [08:01<05:59,  3.43s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  55%|█████▌    | 129/233 [08:05<05:53,  3.39s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  56%|█████▌    | 130/233 [08:09<06:04,  3.54s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  56%|█████▌    | 131/233 [08:14<06:56,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  57%|█████▋    | 132/233 [08:17<06:28,  3.85s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  57%|█████▋    | 133/233 [08:22<06:43,  4.03s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  58%|█████▊    | 134/233 [08:25<06:18,  3.82s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  58%|█████▊    | 135/233 [08:29<06:25,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  58%|█████▊    | 136/233 [08:33<06:06,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  59%|█████▉    | 137/233 [08:36<05:36,  3.51s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  59%|█████▉    | 138/233 [08:39<05:36,  3.54s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  60%|█████▉    | 139/233 [08:42<05:26,  3.48s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  60%|██████    | 140/233 [08:46<05:21,  3.45s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  61%|██████    | 141/233 [08:50<05:40,  3.70s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  61%|██████    | 142/233 [08:53<05:24,  3.56s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  61%|██████▏   | 143/233 [08:57<05:14,  3.49s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  62%|██████▏   | 144/233 [09:00<05:06,  3.44s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  62%|██████▏   | 145/233 [09:03<04:59,  3.40s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  63%|██████▎   | 146/233 [09:07<04:57,  3.41s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  63%|██████▎   | 147/233 [09:09<04:32,  3.17s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  64%|██████▎   | 148/233 [09:13<04:33,  3.22s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  64%|██████▍   | 149/233 [09:16<04:25,  3.16s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  64%|██████▍   | 150/233 [09:24<06:27,  4.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  65%|██████▍   | 151/233 [09:27<05:50,  4.27s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  65%|██████▌   | 152/233 [09:31<05:22,  3.98s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  66%|██████▌   | 153/233 [09:35<05:23,  4.04s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  66%|██████▌   | 154/233 [09:38<05:01,  3.82s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  67%|██████▋   | 155/233 [09:42<05:02,  3.87s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  67%|██████▋   | 156/233 [09:46<05:05,  3.97s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  67%|██████▋   | 157/233 [09:50<05:03,  4.00s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  68%|██████▊   | 158/233 [09:54<04:44,  3.80s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  68%|██████▊   | 159/233 [09:57<04:30,  3.66s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  69%|██████▊   | 160/233 [10:00<04:20,  3.57s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  69%|██████▉   | 161/233 [10:05<04:50,  4.04s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  70%|██████▉   | 162/233 [10:09<04:31,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  70%|██████▉   | 163/233 [10:12<04:18,  3.69s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  70%|███████   | 164/233 [10:16<04:07,  3.59s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  71%|███████   | 165/233 [10:19<04:00,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  71%|███████   | 166/233 [10:22<03:52,  3.47s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  72%|███████▏  | 167/233 [10:26<03:51,  3.50s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  72%|███████▏  | 168/233 [10:29<03:32,  3.27s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  73%|███████▎  | 169/233 [10:34<04:09,  3.89s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  73%|███████▎  | 170/233 [10:38<04:01,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  73%|███████▎  | 171/233 [10:40<03:37,  3.51s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  74%|███████▍  | 172/233 [10:44<03:30,  3.45s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  74%|███████▍  | 173/233 [10:47<03:32,  3.55s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  75%|███████▍  | 174/233 [10:53<03:56,  4.01s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  75%|███████▌  | 175/233 [10:56<03:41,  3.81s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  76%|███████▌  | 176/233 [11:00<03:37,  3.82s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  76%|███████▌  | 177/233 [11:03<03:25,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  76%|███████▋  | 178/233 [11:10<04:23,  4.79s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  77%|███████▋  | 179/233 [11:14<03:57,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  77%|███████▋  | 180/233 [11:19<04:03,  4.59s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  78%|███████▊  | 181/233 [11:22<03:39,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  78%|███████▊  | 182/233 [11:28<03:50,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  79%|███████▊  | 183/233 [11:31<03:28,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  79%|███████▉  | 184/233 [11:34<03:12,  3.92s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  79%|███████▉  | 185/233 [11:38<03:08,  3.93s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  80%|███████▉  | 186/233 [11:42<02:56,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  80%|████████  | 187/233 [11:45<02:46,  3.62s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  81%|████████  | 188/233 [11:48<02:39,  3.55s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  81%|████████  | 189/233 [11:53<02:53,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  82%|████████▏ | 190/233 [11:56<02:41,  3.76s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  82%|████████▏ | 191/233 [12:00<02:32,  3.64s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  82%|████████▏ | 192/233 [12:04<02:37,  3.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  83%|████████▎ | 193/233 [12:07<02:27,  3.69s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  83%|████████▎ | 194/233 [12:12<02:28,  3.81s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  84%|████████▎ | 195/233 [12:14<02:14,  3.55s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  84%|████████▍ | 196/233 [12:18<02:10,  3.52s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  85%|████████▍ | 197/233 [12:22<02:08,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  85%|████████▍ | 198/233 [12:25<02:02,  3.51s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  85%|████████▌ | 199/233 [12:29<02:01,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  86%|████████▌ | 200/233 [12:32<01:56,  3.52s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  86%|████████▋ | 201/233 [12:35<01:50,  3.46s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  87%|████████▋ | 202/233 [12:40<01:57,  3.79s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  87%|████████▋ | 203/233 [12:45<02:04,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  88%|████████▊ | 204/233 [12:48<01:53,  3.91s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  88%|████████▊ | 205/233 [12:52<01:44,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  88%|████████▊ | 206/233 [12:55<01:37,  3.62s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  89%|████████▉ | 207/233 [12:58<01:31,  3.53s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  89%|████████▉ | 208/233 [13:02<01:26,  3.47s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  90%|████████▉ | 209/233 [13:06<01:27,  3.65s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  90%|█████████ | 210/233 [13:10<01:30,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  91%|█████████ | 211/233 [13:14<01:23,  3.77s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  91%|█████████ | 212/233 [13:19<01:26,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  91%|█████████▏| 213/233 [13:22<01:20,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  92%|█████████▏| 214/233 [13:26<01:12,  3.80s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  92%|█████████▏| 215/233 [13:31<01:15,  4.20s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  93%|█████████▎| 216/233 [13:34<01:07,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  93%|█████████▎| 217/233 [13:54<02:21,  8.83s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  94%|█████████▎| 218/233 [13:58<01:47,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  94%|█████████▍| 219/233 [14:08<01:53,  8.14s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  94%|█████████▍| 220/233 [14:12<01:28,  6.78s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  95%|█████████▍| 221/233 [14:16<01:11,  5.98s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  95%|█████████▌| 222/233 [14:19<00:57,  5.20s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  96%|█████████▌| 223/233 [14:23<00:46,  4.65s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  96%|█████████▌| 224/233 [14:26<00:38,  4.26s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  97%|█████████▋| 225/233 [14:29<00:32,  4.01s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  97%|█████████▋| 226/233 [14:33<00:27,  3.93s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  97%|█████████▋| 227/233 [14:36<00:22,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  98%|█████████▊| 228/233 [14:40<00:18,  3.75s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  98%|█████████▊| 229/233 [14:45<00:15,  3.92s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  99%|█████████▊| 230/233 [14:48<00:11,  3.76s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告:  99%|█████████▉| 231/233 [14:51<00:07,  3.63s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告: 100%|█████████▉| 232/233 [14:55<00:03,  3.54s/it]Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# 生成报告: 100%|██████████| 233/233 [14:59<00:00,  3.86s/it]
# ✅ 报告生成完成！
# 成功生成: 233 条
# 跳过: 0 条
# 结果已保存至: /content/drive/MyDrive/medgamma/medgemma_reports_233.csv
#
# --- 前 3 条报告预览 ---
#
# [1] Subject: 10075925
# Ground Truth: Mild pulmonary vascular congestion with mild to moderate interstitial pulmonary edema are new compar...
# Generated: The heart is enlarged. There is mild pulmonary edema. The mediastinum is unremarkable. The pleural s...
#
# [2] Subject: 10174198
# Ground Truth: Lungs are clear without consolidation, effusion, or pneumothorax.  The cardiomediastinal silhouette ...
# Generated: The heart size is normal. The mediastinal contours are unremarkable. The lungs are clear without foc...
#
# [3] Subject: 10199765
# Ground Truth: Subtle patchy opacity along the left heart border on the frontal view, not substantiated on the late...
# Generated: The heart size is mildly enlarged. The mediastinal contours are unremarkable. The lungs are clear wi...

# %% [markdown]
# ## Step 7: RadGraph F1 评估
#
# 使用 RadGraph 指标评估生成报告的质量。
#
# **指标说明：**
# - **RG_E**: Entity F1（实体匹配）
# - **RG_ER**: Entity + Relation F1（实体+关系，论文常用指标）
# - **RG_ER_bar**: Complete Match F1（完全匹配）

# %%
# ⚠️ RadGraph 兼容性修复（必须先运行这个 cell！）
# 修复 transformers 5.x 与 radgraph 的兼容性问题

from transformers import BertTokenizer
from transformers.tokenization_utils_base import PreTrainedTokenizerBase

fixed_methods = []

# 1. 添加 encode_plus 方法
if not hasattr(BertTokenizer, 'encode_plus'):
    def encode_plus_wrapper(self, text, *args, **kwargs):
        return self(text, *args, **kwargs)
    BertTokenizer.encode_plus = encode_plus_wrapper
    fixed_methods.append('encode_plus')

# 2. 添加 build_inputs_with_special_tokens 方法
if not hasattr(BertTokenizer, 'build_inputs_with_special_tokens'):
    def build_inputs_with_special_tokens_wrapper(self, token_ids_0, token_ids_1=None):
        # BERT: [CLS] + tokens_0 + [SEP] + tokens_1 + [SEP]
        if token_ids_1 is None:
            return [self.cls_token_id] + token_ids_0 + [self.sep_token_id]
        return [self.cls_token_id] + token_ids_0 + [self.sep_token_id] + token_ids_1 + [self.sep_token_id]
    BertTokenizer.build_inputs_with_special_tokens = build_inputs_with_special_tokens_wrapper
    fixed_methods.append('build_inputs_with_special_tokens')

# 3. 添加 get_special_tokens_mask 方法（可能也会需要）
if not hasattr(BertTokenizer, 'get_special_tokens_mask'):
    def get_special_tokens_mask_wrapper(
        self, token_ids_0, token_ids_1=None, already_has_special_tokens=False
    ):
        if already_has_special_tokens:
            return super(BertTokenizer, self).get_special_tokens_mask(
                token_ids_0=token_ids_0,
                token_ids_1=token_ids_1,
                already_has_special_tokens=True,
            )
        if token_ids_1 is None:
            return [1] + ([0] * len(token_ids_0)) + [1]
        return [1] + ([0] * len(token_ids_0)) + [1] + ([0] * len(token_ids_1)) + [1]
    BertTokenizer.get_special_tokens_mask = get_special_tokens_mask_wrapper
    fixed_methods.append('get_special_tokens_mask')

if fixed_methods:
    print(f"✅ RadGraph 兼容性修复已应用: {', '.join(fixed_methods)}")
else:
    print("✅ BertTokenizer 已有所有必需方法")
# Out:
# ✅ BertTokenizer 已有所有必需方法

# %%
from radgraph import F1RadGraphimport torchprint("🔍 开始 RadGraph F1 评估...")print(f"评估样本数: {len(df_results)}\n")# 准备数据refs = df_results["Ground_Truth"].tolist()hyps = df_results["Generated_Report"].tolist()# 过滤掉空报告valid_pairs = [(h, r) for h, r in zip(hyps, refs) if h and r and len(h.strip()) > 0]if len(valid_pairs) < len(hyps):    print(f"⚠️ 跳过 {len(hyps) - len(valid_pairs)} 条空报告")hyps_clean, refs_clean = zip(*valid_pairs) if valid_pairs else ([], [])# 初始化 RadGraph（使用 'all' 获取所有指标）f1radgraph = F1RadGraph(reward_level="all")# 计算 F1results = f1radgraph(hyps=list(hyps_clean), refs=list(refs_clean))# 解析返回值：results[0] = (simple, partial, complete)avg_scores = results[0]simple_f1 = float(avg_scores[0])    # RG_ER_bar (Complete Match)partial_f1 = float(avg_scores[1])   # RG_ER (Entity + Relation) ← 论文常用complete_f1 = float(avg_scores[2])  # RG_E (Entity)# 显示结果print("\n" + "="*60)print("MedGemma 1.5 原始版本 RadGraph F1 评估结果（百分制）")print("="*60)print(f"RG_E (Entity):              {complete_f1*100:.2f}")print(f"RG_ER (Entity+Relation):    {partial_f1*100:.2f}  ← 论文常用")print(f"RG_ER_bar (Complete Match): {simple_f1*100:.2f}")print("="*60)# 显示详细统计if len(results) > 1 and isinstance(results[1], tuple) and len(results[1]) >= 3:    simple_scores = results[1][0]    partial_scores = results[1][1]    complete_scores = results[1][2]    print(f"\n详细统计（{len(simple_scores)} 个样本）:")    print(f"  RG_E:       min={min(complete_scores)*100:.2f}, max={max(complete_scores)*100:.2f}, mean={sum(complete_scores)/len(complete_scores)*100:.2f}")    print(f"  RG_ER:      min={min(partial_scores)*100:.2f}, max={max(partial_scores)*100:.2f}, mean={sum(partial_scores)/len(partial_scores)*100:.2f}")    print(f"  RG_ER_bar:  min={min(simple_scores)*100:.2f}, max={max(simple_scores)*100:.2f}, mean={sum(simple_scores)/len(simple_scores)*100:.2f}")if torch.cuda.is_available():    peak_mem = torch.cuda.max_memory_allocated(0) / 1e9    print(f"\nPeak GPU 显存: {peak_mem:.2f} GB")print("\n✅ 评估完成！")
# Out:
# 🔍 开始 RadGraph F1 评估...
# 评估样本数: 233
#
# Using device: cuda:0
# model_type not provided, defaulting to radgraph-xl
#
# ============================================================
# RadGraph F1 评估结果
# ============================================================
# RG_E (Entity):              0.2705
# RG_ER (Entity+Relation):    0.3465  ← 论文常用
# RG_ER_bar (Complete Match): 0.3640
# ============================================================
#
# 详细统计（233 个样本）:
#   RG_E:       min=0.0000, max=0.6667, mean=0.2705
#   RG_ER:      min=0.0000, max=0.7429, mean=0.3465
#   RG_ER_bar:  min=0.0000, max=0.7778, mean=0.3640
#
# Peak GPU 显存: 3.27 GB
#
# ✅ 评估完成！

# %% [markdown]
# ## 附录：RadGraph Patch（如遇到兼容性问题）
#
# 如果 RadGraph 报错 `encode_plus` 相关错误，运行下面的 patch：

# %%
# RadGraph 兼容性修复
import os

radgraph_file = "/usr/local/lib/python3.12/dist-packages/radgraph/allennlp/data/tokenizers/pretrained_transformer_tokenizer.py"

if os.path.exists(radgraph_file):
    content = open(radgraph_file).read()
    if ".encode_plus(" in content:
        open(radgraph_file, "w").write(content.replace(".encode_plus(", "("))
        print("✅ RadGraph patch 已应用")
    else:
        print("✅ RadGraph 已是最新版本，无需 patch")
else:
    print("⚠️ RadGraph 文件未找到")
